# %% [markdown]
# This notebook's goal is to retrieve data from ADFG Alaska, in this case the CSIS - Community Subsistence Information System - database. There is no easy tool to retrieve all informations at a Community level so a method was found to do it through HTML request, this shouldn't be run in parallel as it could shut down the ADFG servers.
#
# Once the data are retrieve, the goal is to categorize a community's subsistence profile based on the subsistence statistics published on the CSIS database.

# %%
import os
import pandas as pd
from multiprocessing.dummy import Pool as ThreadPool #It would greatly reduce the time with post processing but the ADFG server can't handle multiple request

# %%
def dit( url ):
    try :
        df = pd.read_excel(url,engine='xlrd')
        _ = df.to_csv('com-{}.csv'.format(url[85:-26]))
        return df
    except : print('FAILED {}'.format(url[85:-26]))

# %% [markdown]
# A range of 0 to 1000 is used as the community ID are not linear
#
# The HTML request was extracted/found with Firebug on Firefox using event recording, Beautiful Soup could have been used but the structure of the data is really messy

# %%
url = ['http://www.adfg.alaska.gov/sb/CSIS/index.cfm?ADFG=excelDownloads.HarvestExcel&CommID={}&allYears&Category=Harvest'.format(i) for i in range(0,1000)]

# %%
# pool = ThreadPool(2)
# results = pool.map(dit,url[0:1000])
# pool.close()
# pool.join()
# df = pd.concat(results)

#Using the saved dataset to not have to extract again
df = pd.read_csv('~/DL/master_CSIS.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Project_ID', 'Project_Name', 'Community_Code',
#        'Community_Name', 'Study_Year', 'Resource_Code', 'Resource',
#        'Species_Hierarchy', 'Percent_Attempting_to_Harvest',
#        'Percent_Harvesting', 'Percent_Using', 'Percent_Giving_Away',
#        'Percent_Receiving', 'Units', 'Reported_Harvest', 'Conversion_Factor',
#        'Reported_Pounds_Harvested', 'Average_Lbs_Harvested_per_Household',
#        'Estimated_Harvest', 'Lower_Harvest_Amount_Estimate',
#        'Upper_Harvest_Amount_Estimate', 'Estimated_Pounds_Harvested',
#        'Lower_Harvest_Lbs_Estimate', 'Upper_Harvest_Lbs_Estimate',
#        'Per_Capita_Lbs_Harvested', 'Percent_95_CIP',
#        'Percent_Of_Total_Harvest', 'Mean_Per_Capita_Lbs_Used',
#        'Mean_Per_Capita_Grams_per_Day',
#        'NinetyFifth_Confidence_Limit_of_Mean_Use_in_Pounds',
#        'NinetyFifth_Confidence_Limit_of_Mean_Use_in_Grams_per_Day',
#        'NinetyFifth_Confidence_Limit_of_Mean_Use_Grams_per_Day',
#        'Fiftieth_Percentile_Use_Median_User_Grams_per_Day',
#        'NinetyFifth_Percentile_Use_High_End_User_Grams_per_Day',
#        'OneHundreth_Percentile_Use_Top_User_Grams_per_Day', 'ResCatCD'],
#       dtype='object')

# %%
df.shape
# Out:
# (148444, 37)

# %%
df['Code'] = pd.to_numeric([str(i)[0] for i in df['Resource_Code']])

# %%
df1 = df[['Community_Name','Code','Estimated_Pounds_Harvested']].copy()
df1 = df1[(df1['Code']!=0) & (df1['Code']!=9)]

# %%
r = df1.groupby(by=['Community_Name','Code']).sum()
r.head()
# Out:
#                      Estimated_Pounds_Harvested
# Community_Name Code
# Adak           3                         6864.0
# Akhiok         1                       381438.0
#                2                        42633.0
#                3                        74668.0
#                4                         7648.0

# %%
r = r.unstack(level=1)
r.head()
# Out:
#                Estimated_Pounds_Harvested                             \
# Code                                    1            2             3
# Community_Name
# Adak                                  NaN          NaN   6864.000000
# Akhiok                       3.814380e+05   42633.0000  74668.000000
# Akiachak                     2.912090e+06  431622.0000  43363.000000
# Akiak                        8.037090e+05  101900.0000   5007.000000
# Akutan                       2.302708e+05   12179.9998  82038.555424
#
#
# Code                        4             5             6
# Community_Name
# Adak                      NaN           NaN           NaN
# Akhiok            7648.000000  54025.000000   1735.000000
# Akiachak        281428.000000      0.000000  63614.000000
# Akiak            41049.000000    192.000000  24550.000000
# Akutan           24291.107093  21486.455633   6104.583372

# %% [markdown]
# Now that we have what we want, let's just clean up and give appropriate title and calculate percentages

# %%
r.columns = [df['Resource'][df['Resource_Code']==code].values[0] for code in [i * pow(10,8) for i in range(1,7)]]
for i in r.columns:
    r['{}-perc'.format(i)] = (r[i]/r.sum(axis=1))*100

# %% [markdown]
# Then let's drop all lines filled with Nan and reset to 0 all the lines with just a few NaN

# %%
finale = r[[i for i in r.columns[6:12]]].dropna(axis=0,how='all').fillna(0)
finale.index
# Out:
# Index(['Adak', 'Akhiok', 'Akiachak', 'Akiak', 'Akutan', 'Alakanuk', 'Alatna',
#        'Aleknagik', 'Allakaket', 'Allakaket/Alatna',
#        ...
#        'Wainwright', 'Wales', 'West Glenn Highway', 'Whale Pass',
#        'White Mountain', 'Whitestone Logging Camp', 'Whittier', 'Wiseman',
#        'Wrangell', 'Yakutat'],
#       dtype='object', name='Community_Name', length=277)

# %% [markdown]
# In order to build spatial vizualisation we need to find the geographic coordinates for all the communities, we use geopy to do so as it is pretty effective even for Alaska.

# %%
def coordinate(community) :
    from geopy.geocoders import Nominatim
    geolocator = Nominatim()
    comm = '{} Alaska'.format(community)
    try :
        return (community , geolocator.geocode(comm).latitude , geolocator.geocode(comm).longitude)
    except :
        print('Failed {} '.format(community))

# %% [markdown]
# Using multiprocessing to speed up the process and raising a flag for failed queries, most of the missing communities are of low importance so we will just ignore them

# %%
pool = ThreadPool(32)
results = pool.map(coordinate,finale.index)
pool.close()
pool.join()
# Out:
# Failed Fritz Creek Census Designated Place
# Failed Game Creek Census Designated Place
# Failed Hurricane-Broad Pass
# Failed Paxson-Sourdough Failed Nunam Iqua (Sheldon Point)
#
# Failed Mentasta Pass
# Failed Pilot Point / Ugashik
# Failed Slana Homestead North
# Failed Slana Homestead South
# Failed Port San Juan (Evans Island)
# Failed South Wrangell Mountains

# %% [markdown]
# This step seem to be necessary to get the tiles properly working on bokeh, just converting the WSG84 coordinates into web mercator

# %%
from pyproj import Proj, transform
results = [result for result in results if result!= None]
labels = ['place', 'Y', 'X']
geo = pd.DataFrame.from_records(results, columns=labels,index='place')
inProj = Proj(init='epsg:4326')
outProj = Proj(init='epsg:3857')

geo['X'],geo['Y'] = transform(inProj,outProj,geo['X'].values,geo['Y'].values )

# %%
full = pd.concat([finale,geo],axis=1)

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(title="My first interactive plot!")
x_coords = full['X']
y_coords = full['Y']
p.circle(x=x_coords, y=y_coords, size=10, color="red")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9def87d6-46ee-428c-a41b-f7c1431f4d04">Loading BokehJS ...</span>
#     </div>
# GlyphRenderer(id='4a0ca1a1-a85f-42cf-84e8-248d8aedda55', ...)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b9ba091d-f198-4117-94c2-c99eb18a1745"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b9ba091d-f198-4117-94c2-c99eb18a1745");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b9ba091d-f198-4117-94c2-c99eb18a1745");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b9ba091d-f198-4117-94c2-c99eb18a1745' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"55c6fdbc-ea0a-4bd9-844e-b69d4170f230":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"c25f27ac-5995-4150-be52-b5575e300b53","type":"Circle"},{"attributes":{},"id":"e68b9f7a-4a67-418e-a01d-dd878af961dd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"}},"id":"e477d9dd-2b0c-4a17-8f51-947ba3e480ce","type":"SaveTool"},{"attributes":{},"id":"8d0dad90-86e1-4004-93de-bc3529ab6182","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"}},"id":"30838e21-fb19-40dd-bef2-d9c7b952926e","type":"ResetTool"},{"attributes":{"below":[{"id":"04d046df-ae5e-4ebb-a8bc-36b974347cb9","type":"LinearAxis"}],"left":[{"id":"4bdc1672-f725-4134-b578-298b5cc03dc4","type":"LinearAxis"}],"renderers":[{"id":"04d046df-ae5e-4ebb-a8bc-36b974347cb9","type":"LinearAxis"},{"id":"c311cd18-b424-43a2-a91a-6e1f04cb4729","type":"Grid"},{"id":"4bdc1672-f725-4134-b578-298b5cc03dc4","type":"LinearAxis"},{"id":"bd5766be-3a71-486e-8c13-8e6bca075559","type":"Grid"},{"id":"d4553cae-4afd-40fc-9fd8-7d83b64434c4","type":"BoxAnnotation"},{"id":"4a0ca1a1-a85f-42cf-84e8-248d8aedda55","type":"GlyphRenderer"}],"title":{"id":"b2c1adce-ee5e-43c6-beb0-369912f58526","type":"Title"},"tool_events":{"id":"0f44cb3d-e688-4bf5-9821-3ed737367e7a","type":"ToolEvents"},"toolbar":{"id":"3c5476ad-b1c5-4e25-a870-711cc6293a5b","type":"Toolbar"},"x_range":{"id":"e8349534-1412-4d90-b7b5-2b82b6624ceb","type":"DataRange1d"},"x_scale":{"id":"844b0aba-9edf-438d-9a7d-20d40b641d97","type":"LinearScale"},"y_range":{"id":"82876153-333a-4923-82a9-3c6cba7aa6c2","type":"DataRange1d"},"y_scale":{"id":"5256fc55-a766-4cc3-a312-0f64a2e29d60","type":"LinearScale"}},"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"0f44cb3d-e688-4bf5-9821-3ed737367e7a","type":"ToolEvents"},{"attributes":{"plot":null,"text":"My first interactive plot!"},"id":"b2c1adce-ee5e-43c6-beb0-369912f58526","type":"Title"},{"attributes":{},"id":"5256fc55-a766-4cc3-a312-0f64a2e29d60","type":"LinearScale"},{"attributes":{"callback":null},"id":"e8349534-1412-4d90-b7b5-2b82b6624ceb","type":"DataRange1d"},{"attributes":{"plot":{"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"}},"id":"96b5dc1e-675b-41f9-b99e-fffabc58a066","type":"HelpTool"},{"attributes":{"plot":{"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"}},"id":"69f9b0c9-0025-4840-8382-8fc0f8e8a206","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b3147116-14d1-490b-a505-e9349c2c59f0","type":"PanTool"},{"id":"69f9b0c9-0025-4840-8382-8fc0f8e8a206","type":"WheelZoomTool"},{"id":"a32d230a-3360-455d-bcd8-24ac9dc8dc98","type":"BoxZoomTool"},{"id":"e477d9dd-2b0c-4a17-8f51-947ba3e480ce","type":"SaveTool"},{"id":"30838e21-fb19-40dd-bef2-d9c7b952926e","type":"ResetTool"},{"id":"96b5dc1e-675b-41f9-b99e-fffabc58a066","type":"HelpTool"}]},"id":"3c5476ad-b1c5-4e25-a870-711cc6293a5b","type":"Toolbar"},{"attributes":{},"id":"878ebdec-518e-4a4a-b278-50821abf7bfc","type":"BasicTicker"},{"attributes":{"data_source":{"id":"80e53e4f-043f-4206-838c-b60c8deab249","type":"ColumnDataSource"},"glyph":{"id":"7e418d05-1eb7-443a-9223-9b8a65b9b5f5","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c25f27ac-5995-4150-be52-b5575e300b53","type":"Circle"},"selection_glyph":null},"id":"4a0ca1a1-a85f-42cf-84e8-248d8aedda55","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2274cb6f-5d1e-4e37-ba8c-c1c2fae9e1e6","subtype":"Figure","type":"Plot"},"ticker":{"id":"878ebdec-518e-4a4a-b278-50821abf7bfc","type":"BasicTicker"}},"id":"c311cd1 ...

# %%
del p

# %%
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, output_notebook, show, save
from bokeh.tile_providers import STAMEN_TERRAIN
my_hover = HoverTool()
output_notebook()
source = ColumnDataSource(full)
my_hover = HoverTool()
my_hover.tooltips = [
    ("Place", "@index"),
    ("Fish", '@{Fish-perc}'),
    ("Land Mammal", '@{Land Mammals-perc}'),
    ("Bird and Eggs", '@{Birds and Eggs-perc}'),
    ("Marine Mammal", "@{Marine Mammals-perc}"),
    ("Marine Invertebrates", '@{Marine Invertebrates-perc}'),
    ("Vegetation", "@{Vegetation-perc}")
]
p = figure(title="CSIS database visualisation")
x_coords = full['X']
y_coords = full['Y']
p.circle(x='X', y='Y', source = source , size=5, color="red")
p.add_tools(my_hover)
p.add_tile(STAMEN_TERRAIN)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="538086e3-bd9d-4a2c-af63-a2713cdbe848">Loading BokehJS ...</span>
#     </div>
# TileRenderer(id='363dcdf5-ec36-49a1-80fb-1385d20bf4f7', ...)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa7297a4-b1a0-4375-80ee-f670d34ebf62"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa7297a4-b1a0-4375-80ee-f670d34ebf62");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa7297a4-b1a0-4375-80ee-f670d34ebf62");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa7297a4-b1a0-4375-80ee-f670d34ebf62' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3b1d6231-dc07-4dd5-996e-aded1d750946":{"roots":{"references":[{"attributes":{"callback":null},"id":"b7499868-cbc7-4175-b8b7-7510071ba821","type":"DataRange1d"},{"attributes":{},"id":"9a1cb680-eacc-45c0-84ce-1fac17d1f166","type":"BasicTicker"},{"attributes":{},"id":"839bced9-4c9e-454d-bbd7-028b26ada125","type":"BasicTicker"},{"attributes":{"callback":null},"id":"d18df4ba-3060-4bd7-9ed6-8a32d162019b","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4f73b6bc-5f0f-449c-9c5e-f8965e90a856","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"13ed09fc-a8f3-45ac-b601-50bc628b994f","type":"PanTool"},{"id":"bb8c11df-77e5-4fe0-ab58-24cefa4f8f03","type":"WheelZoomTool"},{"id":"6a7955ac-270b-4743-acb4-32c51337a874","type":"BoxZoomTool"},{"id":"215f14f9-7ec5-44fa-b7a9-5bdd0e80bb36","type":"SaveTool"},{"id":"f9e82043-8597-4fab-943d-663cf0092fc9","type":"ResetTool"},{"id":"cf3978ab-48b0-419f-a300-9bd5472f8091","type":"HelpTool"},{"id":"e48fa812-1acf-4476-a52b-7e0f5ca506a8","type":"HoverTool"}]},"id":"3dfb79a9-f0b4-436a-8f96-855bc53eb0fa","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"X"},"y":{"field":"Y"}},"id":"be262f54-ebed-40ff-a04f-0db7ac029998","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"0b3e19ed-3000-4b0a-a5f3-728784736059","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a1cb680-eacc-45c0-84ce-1fac17d1f166","type":"BasicTicker"}},"id":"c244180e-2f33-4a87-98eb-9ab33a9e07ed","type":"Grid"},{"attributes":{"below":[{"id":"e923eda5-264f-44bf-8fcc-1a335c4f5392","type":"LinearAxis"}],"left":[{"id":"7d3324cc-efbd-4a3a-ab67-cc1d0cd88d22","type":"LinearAxis"}],"renderers":[{"id":"e923eda5-264f-44bf-8fcc-1a335c4f5392","type":"LinearAxis"},{"id":"26007e31-e78c-4e54-8955-3120f6dc8198","type":"Grid"},{"id":"7d3324cc-efbd-4a3a-ab67-cc1d0cd88d22","type":"LinearAxis"},{"id":"c244180e-2f33-4a87-98eb-9ab33a9e07ed","type":"Grid"},{"id":"4f73b6bc-5f0f-449c-9c5e-f8965e90a856","type":"BoxAnnotation"},{"id":"accdf32d-d662-479d-b381-0275e5f0ae5d","type":"GlyphRenderer"},{"id":"363dcdf5-ec36-49a1-80fb-1385d20bf4f7","type":"TileRenderer"}],"title":{"id":"3c6f1e59-aa3f-4136-9b53-fe2b063ac856","type":"Title"},"tool_events":{"id":"8b8b3bf1-e5f9-4baf-bba8-0804d298bdec","type":"ToolEvents"},"toolbar":{"id":"3dfb79a9-f0b4-436a-8f96-855bc53eb0fa","type":"Toolbar"},"x_range":{"id":"d18df4ba-3060-4bd7-9ed6-8a32d162019b","type":"DataRange1d"},"x_scale":{"id":"ac80d994-14f1-415d-8db6-f17b404683e1","type":"LinearScale"},"y_range":{"id":"b7499868-cbc7-4175-b8b7-7510071ba821","type":"DataRange1d"},"y_scale":{"id":"ed41e1b9-bbdb-4e81-a649-6838c4ddc382","type":"LinearScale"}},"id":"0b3e19ed-3000-4b0a-a5f3-728784736059","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["Fish-perc","Land Mammals-perc","Marine Mammals-perc","Birds and Eggs-perc","Marine Invertebrates-perc","Vegetation-perc","Y","X","index"],"data":{"Birds and Eggs-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Fish-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Land Mammals-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Marine Invertebrates-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Marine Mammals-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Vegetation-perc":{"__ndarray__":"...","dtype":"float64","shape":[277]},"X":{"__ndarray__":"...","dtype":"float64","shape":[277]},"Y":{"__ndarray__":"...","dtype":"float64","shape":[277]},"in ...

# %% [markdown]
# This tutorial was used as inspiration for this piece of code https://automating-gis-processes.github.io/2016/Lesson5-interactive-map-bokeh.html
